# %%
# !git clone https://github.com/jonruida/PowerBI_Scraper-webscraping
# Out:
# Cloning into 'PowerBI_Scraper-webscraping'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 14 (delta 4), reused 7 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 12.26 KiB | 6.13 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# !pip install prefect
# Out:
# Collecting prefect
#   Downloading prefect-2.20.4-py3-none-any.whl.metadata (12 kB)
# Collecting aiosqlite<1.0.0,>=0.17.0 (from prefect)
#   Downloading aiosqlite-0.20.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting alembic<2.0.0,>=1.7.5 (from prefect)
#   Downloading alembic-1.13.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting apprise<2.0.0,>=1.8.0 (from prefect)
#   Downloading apprise-1.9.0-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.7/51.7 kB 3.4 MB/s eta 0:00:00
# Collecting asyncpg<1.0.0,>=0.23 (from prefect)
#   Downloading asyncpg-0.29.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: click<8.2,>=8.0 in /usr/local/lib/python3.10/dist-packages (from prefect) (8.1.7)
# Requirement already satisfied: cryptography>=36.0.1 in /usr/local/lib/python3.10/dist-packages (from prefect) (43.0.0)
# Collecting dateparser<2.0.0,>=1.1.1 (from prefect)
#   Downloading dateparser-1.2.0-py2.py3-none-any.whl.metadata (28 kB)
# Collecting docker<8.0,>=4.0 (from prefect)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: graphviz>=0.20.1 in /usr/local/lib/python3.10/dist-packages (from prefect) (0.20.3)
# Requirement already satisfied: jinja2<4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from prefect) (3.1.4)
# Collecting jinja2-humanize-extension>=0.4.0 (from prefect)
#   Downloading jinja2_humanize_extension-0.4.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: humanize<5.0.0,>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from prefect) (4.10.0)
# Collecting kubernetes<30.0.0,>=24.2.0 (from prefect)
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pytz<2025,>=2021.1 in /usr/local/lib/python3.10/dist-packages (from prefect) (2024.1)
# Collecting readchar<5.0.0,>=4.0.0 (from prefect)
#   Downloading readchar-4.2.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: sqlalchemy!=1.4.33,<3.0.0,>=1.4.22 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy[asyncio]!=1.4.33,<3.0.0,>=1.4.22->prefect) (2.0.32)
# Requirement already satisfied: typer!=0.12.2,<0.13.0,>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from prefect) (0.12.5)
# Collecting anyio<5.0.0,>=4.4.0 (from prefect)
#   Downloading anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting asgi-lifespan<3.0,>=1.0 (from prefect)
#   Downloading asgi_lifespan-2.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: cachetools<6.0,>=5.3 in /usr/local/lib/python3.10/dist-packages (from prefect) (5.5.0)
# Requirement already satisfied: cloudpickle<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from prefect) (2.2.1)
# Collecting coolname<3.0.0,>=1.0.4 (from prefect)
#   Downloading coolname-2.2.0-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting croniter<3.0.0,>=1.0.12 (from prefect)
#   Downloading croniter-2.0.7-py2.py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from prefect) (2024.6.1)
# Requirement already satisfied: exceptiongroup>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from prefect) (1.2.2)
# Collecting griffe<2.0.0,>=0.49.0 (from prefect)
#   Downloading griffe-1.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting httpcore<2.0.0,>=1.0.5 (from prefect)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting httpx!=0.23.2,>=0.23 (from httpx[http2]!=0.23.2,>=0.23->prefect)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: importlib-resources<6.5.0,>=6.1.3 in /usr/local/lib/python3.10/dist-packages (from prefect) (6.4.4)
# Collecting jsonpatch<2.0,>=1.32 (from prefect)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from prefect) (4.23.0)
# Collecting orjson<4.0,>=3.7 (from prefect)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging<24.3,>=21.3 in /usr/local/lib/python3.10/dist-packages (from prefect) (24.1)
# Collecting pathspec>=0.8.0 (from prefect)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: pydantic!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->prefect) (2.8.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from prefect) (2.20.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from prefect) (2.8.2)
# Requirement already satisfied: python-slugify<9.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from prefect) (8.0.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from prefect) (6.0.2)
# Collecting rfc3339-validator<0.2.0,>=0.1.4 (from prefect)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: rich<14.0,>=11.0 in /usr/local/lib/python3.10/dist-packages (from prefect) (13.8.0)
# Collecting ruamel.yaml>=0.17.0 (from prefect)
#   Downloading ruamel.yaml-0.18.6-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: sniffio<2.0.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from prefect) (1.3.1)
# Requirement already satisfied: toml>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from prefect) (0.10.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from prefect) (4.12.2)
# Collecting ujson<6.0.0,>=5.8.0 (from prefect)
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.3 kB)
# Collecting uvicorn!=0.29.0,>=0.14.0 (from prefect)
#   Downloading uvicorn-0.30.6-py3-none-any.whl.metadata (6.6 kB)
# Collecting websockets<14.0,>=10.4 (from prefect)
#   Downloading websockets-13.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: itsdangerous in /usr/local/lib/python3.10/dist-packages (from prefect) (2.2.0)
# Collecting python-multipart>=0.0.7 (from prefect)
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Collecting pendulum<3.0 (from prefect)
#   Downloading pendulum-2.1.2.tar.gz (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 kB 5.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting Mako (from alembic<2.0.0,>=1.7.5->prefect)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0.0,>=4.4.0->prefect) (3.8)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from apprise<2.0.0,>=1.8.0->prefect) (2024.7.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from apprise<2.0.0,>=1.8.0->prefect) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from apprise<2.0.0,>=1.8.0->prefect) (1.3.1)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from apprise<2.0.0,>=1.8.0->prefect) (3.7)
# Requirement already satisfied: async-timeout>=4.0.3 in /usr/local/lib/python3.10/dist-packages (from asyncpg<1.0.0,>=0.23->prefect) (4.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.1->prefect) (1.17.0)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.10/dist-packages (from dateparser<2.0.0,>=1.1.1->prefect) (2024.5.15)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser<2.0.0,>=1.1.1->prefect) (5.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from docker<8.0,>=4.0->prefect) (2.0.7)
# Collecting colorama>=0.4 (from griffe<2.0.0,>=0.49.0->prefect)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting h11<0.15,>=0.13 (from httpcore<2.0.0,>=1.0.5->prefect)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting h2<5,>=3 (from httpx[http2]!=0.23.2,>=0.23->prefect)
#   Downloading h2-4.1.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<4.0.0,>=3.0.0->prefect) (2.1.5)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.32->prefect)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->prefect) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->prefect) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->prefect) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->prefect) (0.20.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes<30.0.0,>=24.2.0->prefect) (1.16.0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes<30.0.0,>=24.2.0->prefect) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes<30.0.0,>=24.2.0->prefect) (1.8.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes<30.0.0,>=24.2.0->prefect) (3.2.2)
# Collecting pytzdata>=2020.1 (from pendulum<3.0->prefect)
#   Downloading pytzdata-2020.1-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->prefect) (0.7.0)
# Collecting email-validator>=2.0.0 (from pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->prefect)
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify<9.0,>=5.0->prefect) (1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0,>=11.0->prefect) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0,>=11.0->prefect) (2.16.1)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.0->prefect)
#   Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy!=1.4.33,<3.0.0,>=1.4.22->sqlalchemy[asyncio]!=1.4.33,<3.0.0,>=1.4.22->prefect) (3.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer!=0.12.2,<0.13.0,>=0.12.0->prefect) (1.5.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.1->prefect) (2.22)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->prefect)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes<30.0.0,>=24.2.0->prefect) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes<30.0.0,>=24.2.0->prefect) (4.9)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect)
#   Downloading hyperframe-6.0.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect)
#   Downloading hpack-4.0.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0,>=11.0->prefect) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->apprise<2.0.0,>=1.8.0->prefect) (3.3.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes<30.0.0,>=24.2.0->prefect) (0.6.0)
# Downloading prefect-2.20.4-py3-none-any.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 53.1 MB/s eta 0:00:00
# Downloading aiosqlite-0.20.0-py3-none-any.whl (15 kB)
# Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.0/233.0 kB 16.6 MB/s eta 0:00:00
# Downloading anyio-4.4.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.0 MB/s eta 0:00:00
# Downloading apprise-1.9.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 40.6 MB/s eta 0:00:00
# Downloading asgi_lifespan-2.1.0-py3-none-any.whl (10 kB)
# Downloading asyncpg-0.29.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 61.9 MB/s eta 0:00:00
# Downloading coolname-2.2.0-py2.py3-none-any.whl (37 kB)
# Downloading croniter-2.0.7-py2.py3-none-any.whl (21 kB)
# Downloading dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 19.9 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 10.5 MB/s eta 0:00:00
# Downloading griffe-1.2.0-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.9/126.9 kB 8.9 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.6 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.9 MB/s eta 0:00:00
# Downloading jinja2_humanize_extension-0.4.0-py3-none-any.whl (4.8 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 36.3 MB/s eta 0:00:00
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 10.6 MB/s eta 0:00:00
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading readchar-4.2.0-py3-none-any.whl (9.3 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 9.2 MB/s eta 0:00:00
# Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 4.0 MB/s eta 0:00:00
# Downloading uvicorn-0.30.6-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.4 MB/s eta 0:00:00
# Downloading websockets-13.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.3/157.3 kB 9.8 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.2 MB/s eta 0:00:00
# Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.0 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading pytzdata-2020.1-py2.py3-none-any.whl (489 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.0/490.0 kB 24.6 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 25.4 MB/s eta 0:00:00
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 4.5 MB/s eta 0:00:00
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 18.4 MB/s eta 0:00:00
# Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Building wheels for collected packages: pendulum
#   Building wheel for pendulum (pyproject.toml) ... done
#   Created wheel for pendulum: filename=pendulum-2.1.2-cp310-cp310-manylinux_2_35_x86_64.whl size=158451 sha256=30e22d17274d82e5ee07e5a016ee501d976e1c5e3982ae95511345488ed7416c
#   Stored in directory: /root/.cache/pip/wheels/2e/41/ed/f113e4c9dc10f6c846d69f412e9cd9aa429960a3e2e485a4f9
# Successfully built pendulum
# Installing collected packages: coolname, websockets, ujson, ruamel.yaml.clib, rfc3339-validator, readchar, pytzdata, python-multipart, pathspec, orjson, Mako, jsonpointer, hyperframe, hpack, h11, dnspython, colorama, asyncpg, asgi-lifespan, anyio, aiosqlite, uvicorn, ruamel.yaml, pendulum, jsonpatch, jinja2-humanize-extension, httpcore, h2, griffe, email-validator, docker, dateparser, croniter, alembic, kubernetes, httpx, apprise, prefect
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.7.1
#     Uninstalling anyio-3.7.1:
#       Successfully uninstalled anyio-3.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-server 1.24.0 requires anyio<4,>=3.1.0, but you have anyio 4.4.0 which is incompatible.
# Successfully installed Mako-1.3.5 aiosqlite-0.20.0 alembic-1.13.2 anyio-4.4.0 apprise-1.9.0 asgi-lifespan-2.1.0 asyncpg-0.29.0 colorama-0.4.6 coolname-2.2.0 croniter-2.0.7 dateparser-1.2.0 dnspython-2.6.1 docker-7.1.0 email-validator-2.2.0 griffe-1.2.0 h11-0.14.0 h2-4.1.0 hpack-4.0.0 httpcore-1.0.5 httpx-0.27.2 hyperframe-6.0.1 jinja2-humanize-extension-0.4.0 jsonpatch-1.33 jsonpointer-3.0.0 kubernetes-29.0.0 orjson-3.10.7 pathspec-0.12.1 pendulum-2.1.2 prefect-2.20.4 python-multipart-0.0.9 pytzdata-2020.1 readchar-4.2.0 rfc3339-validator-0.1.4 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.8 ujson-5.10.0 uvicorn-0.30.6 websockets-13.0.1

# %%
# !pip install prefect_aws
# Out:
# Collecting prefect_aws
#   Downloading prefect_aws-0.4.19-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from prefect_aws) (1.2.2)
# Collecting boto3>=1.24.53 (from prefect_aws)
#   Downloading boto3-1.35.10-py3-none-any.whl.metadata (6.6 kB)
# Collecting botocore>=1.27.53 (from prefect_aws)
#   Downloading botocore-1.35.10-py3-none-any.whl.metadata (5.7 kB)
# Collecting mypy-boto3-s3>=1.24.94 (from prefect_aws)
#   Downloading mypy_boto3_s3-1.35.2-py3-none-any.whl.metadata (17 kB)
# Collecting mypy-boto3-secretsmanager>=1.26.49 (from prefect_aws)
#   Downloading mypy_boto3_secretsmanager-1.35.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: prefect<3.0.0,>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from prefect_aws) (2.20.4)
# Requirement already satisfied: pyparsing>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from prefect_aws) (3.1.4)
# Requirement already satisfied: tenacity>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from prefect_aws) (9.0.0)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.24.53->prefect_aws)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3>=1.24.53->prefect_aws)
#   Downloading s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore>=1.27.53->prefect_aws) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore>=1.27.53->prefect_aws) (2.0.7)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from mypy-boto3-s3>=1.24.94->prefect_aws) (4.12.2)
# Requirement already satisfied: aiosqlite<1.0.0,>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (0.20.0)
# Requirement already satisfied: alembic<2.0.0,>=1.7.5 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (1.13.2)
# Requirement already satisfied: apprise<2.0.0,>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (1.9.0)
# Requirement already satisfied: asyncpg<1.0.0,>=0.23 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (0.29.0)
# Requirement already satisfied: click<8.2,>=8.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (8.1.7)
# Requirement already satisfied: cryptography>=36.0.1 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (43.0.0)
# Requirement already satisfied: dateparser<2.0.0,>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (1.2.0)
# Requirement already satisfied: docker<8.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (7.1.0)
# Requirement already satisfied: graphviz>=0.20.1 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (0.20.3)
# Requirement already satisfied: jinja2<4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (3.1.4)
# Requirement already satisfied: jinja2-humanize-extension>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (0.4.0)
# Requirement already satisfied: humanize<5.0.0,>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (4.10.0)
# Requirement already satisfied: kubernetes<30.0.0,>=24.2.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (29.0.0)
# Requirement already satisfied: pytz<2025,>=2021.1 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (2024.1)
# Requirement already satisfied: readchar<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (4.2.0)
# Requirement already satisfied: sqlalchemy!=1.4.33,<3.0.0,>=1.4.22 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy[asyncio]!=1.4.33,<3.0.0,>=1.4.22->prefect<3.0.0,>=2.20.0->prefect_aws) (2.0.32)
# Requirement already satisfied: typer!=0.12.2,<0.13.0,>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (0.12.5)
# Requirement already satisfied: anyio<5.0.0,>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (4.4.0)
# Requirement already satisfied: asgi-lifespan<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (2.1.0)
# Requirement already satisfied: cachetools<6.0,>=5.3 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (5.5.0)
# Requirement already satisfied: cloudpickle<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (2.2.1)
# Requirement already satisfied: coolname<3.0.0,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (2.2.0)
# Requirement already satisfied: croniter<3.0.0,>=1.0.12 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (2.0.7)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (2024.6.1)
# Requirement already satisfied: griffe<2.0.0,>=0.49.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (1.2.0)
# Requirement already satisfied: httpcore<2.0.0,>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (1.0.5)
# Requirement already satisfied: httpx!=0.23.2,>=0.23 in /usr/local/lib/python3.10/dist-packages (from httpx[http2]!=0.23.2,>=0.23->prefect<3.0.0,>=2.20.0->prefect_aws) (0.27.2)
# Requirement already satisfied: importlib-resources<6.5.0,>=6.1.3 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (6.4.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.32 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (1.33)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (4.23.0)
# Requirement already satisfied: orjson<4.0,>=3.7 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (3.10.7)
# Requirement already satisfied: packaging<24.3,>=21.3 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (24.1)
# Requirement already satisfied: pathspec>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (0.12.1)
# Requirement already satisfied: pydantic!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->prefect<3.0.0,>=2.20.0->prefect_aws) (2.8.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (2.20.1)
# Requirement already satisfied: python-slugify<9.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (8.0.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (6.0.2)
# Requirement already satisfied: rfc3339-validator<0.2.0,>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (0.1.4)
# Requirement already satisfied: rich<14.0,>=11.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (13.8.0)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (0.18.6)
# Requirement already satisfied: sniffio<2.0.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (1.3.1)
# Requirement already satisfied: toml>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (0.10.2)
# Requirement already satisfied: ujson<6.0.0,>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (5.10.0)
# Requirement already satisfied: uvicorn!=0.29.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (0.30.6)
# Requirement already satisfied: websockets<14.0,>=10.4 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (13.0.1)
# Requirement already satisfied: itsdangerous in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (2.2.0)
# Requirement already satisfied: python-multipart>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (0.0.9)
# Requirement already satisfied: pendulum<3.0 in /usr/local/lib/python3.10/dist-packages (from prefect<3.0.0,>=2.20.0->prefect_aws) (2.1.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic<2.0.0,>=1.7.5->prefect<3.0.0,>=2.20.0->prefect_aws) (1.3.5)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0.0,>=4.4.0->prefect<3.0.0,>=2.20.0->prefect_aws) (3.8)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from apprise<2.0.0,>=1.8.0->prefect<3.0.0,>=2.20.0->prefect_aws) (2024.7.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from apprise<2.0.0,>=1.8.0->prefect<3.0.0,>=2.20.0->prefect_aws) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from apprise<2.0.0,>=1.8.0->prefect<3.0.0,>=2.20.0->prefect_aws) (1.3.1)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from apprise<2.0.0,>=1.8.0->prefect<3.0.0,>=2.20.0->prefect_aws) (3.7)
# Requirement already satisfied: async-timeout>=4.0.3 in /usr/local/lib/python3.10/dist-packages (from asyncpg<1.0.0,>=0.23->prefect<3.0.0,>=2.20.0->prefect_aws) (4.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.1->prefect<3.0.0,>=2.20.0->prefect_aws) (1.17.0)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.10/dist-packages (from dateparser<2.0.0,>=1.1.1->prefect<3.0.0,>=2.20.0->prefect_aws) (2024.5.15)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser<2.0.0,>=1.1.1->prefect<3.0.0,>=2.20.0->prefect_aws) (5.2)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.10/dist-packages (from griffe<2.0.0,>=0.49.0->prefect<3.0.0,>=2.20.0->prefect_aws) (0.4.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore<2.0.0,>=1.0.5->prefect<3.0.0,>=2.20.0->prefect_aws) (0.14.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.10/dist-packages (from httpx[http2]!=0.23.2,>=0.23->prefect<3.0.0,>=2.20.0->prefect_aws) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<4.0.0,>=3.0.0->prefect<3.0.0,>=2.20.0->prefect_aws) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.32->prefect<3.0.0,>=2.20.0->prefect_aws) (3.0.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->prefect<3.0.0,>=2.20.0->prefect_aws) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->prefect<3.0.0,>=2.20.0->prefect_aws) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->prefect<3.0.0,>=2.20.0->prefect_aws) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.0.0->prefect<3.0.0,>=2.20.0->prefect_aws) (0.20.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes<30.0.0,>=24.2.0->prefect<3.0.0,>=2.20.0->prefect_aws) (1.16.0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes<30.0.0,>=24.2.0->prefect<3.0.0,>=2.20.0->prefect_aws) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes<30.0.0,>=24.2.0->prefect<3.0.0,>=2.20.0->prefect_aws) (1.8.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes<30.0.0,>=24.2.0->prefect<3.0.0,>=2.20.0->prefect_aws) (3.2.2)
# Requirement already satisfied: pytzdata>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pendulum<3.0->prefect<3.0.0,>=2.20.0->prefect_aws) (2020.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->prefect<3.0.0,>=2.20.0->prefect_aws) (0.7.0)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->prefect<3.0.0,>=2.20.0->prefect_aws) (2.2.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify<9.0,>=5.0->prefect<3.0.0,>=2.20.0->prefect_aws) (1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0,>=11.0->prefect<3.0.0,>=2.20.0->prefect_aws) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0,>=11.0->prefect<3.0.0,>=2.20.0->prefect_aws) (2.16.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from ruamel.yaml>=0.17.0->prefect<3.0.0,>=2.20.0->prefect_aws) (0.2.8)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy!=1.4.33,<3.0.0,>=1.4.22->sqlalchemy[asyncio]!=1.4.33,<3.0.0,>=1.4.22->prefect<3.0.0,>=2.20.0->prefect_aws) (3.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer!=0.12.2,<0.13.0,>=0.12.0->prefect<3.0.0,>=2.20.0->prefect_aws) (1.5.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.1->prefect<3.0.0,>=2.20.0->prefect_aws) (2.22)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email-validator>=2.0.0->pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->prefect<3.0.0,>=2.20.0->prefect_aws) (2.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes<30.0.0,>=24.2.0->prefect<3.0.0,>=2.20.0->prefect_aws) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes<30.0.0,>=24.2.0->prefect<3.0.0,>=2.20.0->prefect_aws) (4.9)
# Requirement already satisfied: hyperframe<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect<3.0.0,>=2.20.0->prefect_aws) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect<3.0.0,>=2.20.0->prefect_aws) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0,>=11.0->prefect<3.0.0,>=2.20.0->prefect_aws) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->apprise<2.0.0,>=1.8.0->prefect<3.0.0,>=2.20.0->prefect_aws) (3.3.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes<30.0.0,>=24.2.0->prefect<3.0.0,>=2.20.0->prefect_aws) (0.6.0)
# Downloading prefect_aws-0.4.19-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 3.7 MB/s eta 0:00:00
# Downloading boto3-1.35.10-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 8.7 MB/s eta 0:00:00
# Downloading botocore-1.35.10-py3-none-any.whl (12.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 60.0 MB/s eta 0:00:00
# Downloading mypy_boto3_s3-1.35.2-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 5.3 MB/s eta 0:00:00
# Downloading mypy_boto3_secretsmanager-1.35.0-py3-none-any.whl (26 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: mypy-boto3-secretsmanager, mypy-boto3-s3, jmespath, botocore, s3transfer, boto3, prefect_aws
# Successfully installed boto3-1.35.10 botocore-1.35.10 jmespath-1.0.1 mypy-boto3-s3-1.35.2 mypy-boto3-secretsmanager-1.35.0 prefect_aws-0.4.19 s3transfer-0.10.2

# %%
####################
# Author : Kulwinder K.
# Date : 12/12/2023
# This script scrapes the Power BI dashboard from the below website
# https://www.un.org/techenvoy/global-digital-compact
# and gives back the CSV file
# It calls json_to_csv.py file inside the script.
####################
# Co-Author : Emmanuel Letremble
# Date : 08/01/2024
# Improved the script to run in less than 1 min instead of about 1H
#####################

"""
ETL Script for Scraping UN Power BI Dashboard

This script defines the Prefect flow for scraping data from the UN Power BI dashboard.

Functions:
- page_1_scraping: Task to scrape data from page 1 of the Power BI dashboard.
- page_2_scraping: Task to scrape data from page 2 of the Power BI dashboard and merge it with existing data.

Flow:
- omdena_ungdc_etl_scrap_pbi_parent: Prefect flow for scraping data from the UN Power BI dashboard.
  - Scrapes data from page 1.
  - Sets record IDs for page 2.
  - Scrapes data from page 2 and merges it with existing data.

Parameters:
None

Returns:
None
"""

import requests
from pathlib import Path
from typing import Dict, Any

from prefect import flow, task
from prefect_aws import S3Bucket

# from etl_common import write_AWS

import pandas as pd
import sys
sys.path.append('/content/PowerBI_Scraper-webscraping')
from json_to_csv import extract

# %%
def page_1_scraping(
    api_url: str, payload: Dict[str, Any], headers: Dict[str, str]
) -> pd.DataFrame:
    """
    Task to scrape data from page 1 of the Power BI dashboard.

    Parameters:
    - api_url (str): The API URL for the Power BI dashboard.
    - payload (Dict[str, Any]): The JSON payload for the API request.
    - headers (Dict[str, str]): The headers for the API request.

    Returns:
    - pd.DataFrame: The scraped data from page 1.
    """

    print(">>> MAIN TABLE")



    table_data = requests.post(api_url, json=payload, headers=headers).json()
    print(table_data)

    return extract(table_data)



def page_2_scraping(
    api_url: str, payload_p2: Dict[str, Any], headers: Dict[str, str], df: pd.DataFrame
) -> pd.DataFrame:
    """
    Task to scrape data from page 2 of the Power BI dashboard and merge it with existing data.

    Parameters:
    - api_url (str): The API URL for the Power BI dashboard.
    - payload_p2 (Dict[str, Any]): The JSON payload for the API request for page 2.
    - headers (Dict[str, str]): The headers for the API request.
    - df (pd.DataFrame): The existing DataFrame.

    Returns:
    - pd.DataFrame: The DataFrame with additional columns scraped from page 2.
    """

    # SET TOPICS
    # Topic names are manually added from the Page 2 of Power BI
    # It would be better if this is also automated to make it more agile.
    topics = [
        "Accountability for Discrimination/Misleading Content",
        "Connect all People",
        "Digital Commons",
        "Human Rights Online",
        "Internet Fragmentation",
        "Other Area",
        "Protect Data",
        "Regulation of AI",
    ]

    # POPULATE TOPICS
    for topic in topics:
        print(">>> TOPIC:", topic)
        clean_topic = topic.replace(" ", "_").replace("/", "_")

        payload_p2["queries"][0]["Query"]["Commands"][0][
            "SemanticQueryDataShapeCommand"
        ]["Query"]["Where"][0]["Condition"]["In"]["Values"][0][0]["Literal"][
            "Value"
        ] = f"'{topic}'"

        result = requests.post(api_url, json=payload_p2, headers=headers).json()
        query_df = extract(result)

        # Merge the `Core Principles` and `Commitments, pledges or actions` columns with the existing DF
        cols = ["Record ID", "Core Principles", "Commitments, pledges or actions"]
        tmp_df = query_df.loc[:, cols]
        tmp_df.rename(
            columns={
                "Core Principles": f"Core_Principle__{clean_topic}",
                "Commitments, pledges or actions": f"Commitments_pledges_or_actions__{clean_topic}",
            },
            inplace=True,
        )

        left = df.set_index("Record ID", drop=False)
        right = tmp_df.set_index("Record ID", drop=True)
        df = left.join(right, how="left", lsuffix="", rsuffix=f"__{clean_topic}")

    else:
        print(">>> PROCESS DESCRIPTION")
        # Merge the `Process description` column on the last call
        left = df.set_index("Record ID", drop=False)

        tmp_df = query_df.loc[:, ["Record ID", "Process description"]]
        right = tmp_df.set_index("Record ID", drop=True)

        df = left.join(right, how="left", lsuffix="", rsuffix=f"")

    return df


def omdena_ungdc_etl_scrap_pbi_parent() -> None:
    """
    Prefect flow for scraping data from the UN Power BI dashboard.

    Returns:
    None
    """

    # payload for tables and second page sections
    payload_p1 = {
        "version": "1.0.0",
        "queries": [
            {
                "Query": {
                    "Commands": [
                        {
                            "SemanticQueryDataShapeCommand": {
                                "Query": {
                                    "Version": 2,
                                    "From": [
                                        {
                                            "Name": "d",
                                            "Entity": "Demographics",
                                            "Type": 0,
                                        },
                                        {
                                            "Name": "a",
                                            "Entity": "All Areas combined",
                                            "Type": 0,
                                        },
                                    ],
                                    "Select": [
                                        {
                                            "Column": {
                                                "Expression": {
                                                    "SourceRef": {"Source": "d"}
                                                },
                                                "Property": "Type",
                                            },
                                            "Name": "Demographics.Type",
                                        },
                                        {
                                            "Column": {
                                                "Expression": {
                                                    "SourceRef": {"Source": "d"}
                                                },
                                                "Property": "Location formatted",
                                            },
                                            "Name": "Demographics.Location formatted",
                                        },
                                        {
                                            "Column": {
                                                "Expression": {
                                                    "SourceRef": {"Source": "d"}
                                                },
                                                "Property": "Contact Name",
                                            },
                                            "Name": "Demographics.Contact Name",
                                        },
                                        {
                                            "Column": {
                                                "Expression": {
                                                    "SourceRef": {"Source": "d"}
                                                },
                                                "Property": "Entity Name",
                                            },
                                            "Name": "Demographics.Entity Name",
                                        },
                                        {
                                            "Column": {
                                                "Expression": {
                                                    "SourceRef": {"Source": "a"}
                                                },
                                                "Property": "Record ID",
                                            },
                                            "Name": "All Areas combined.Record ID",
                                            "NativeReferenceName": "Record ID1",
                                        },
                                    ],
                                    "Where": [
                                        {
                                            "Condition": {
                                                "In": {
                                                    "Expressions": [
                                                        {
                                                            "Column": {
                                                                "Expression": {
                                                                    "SourceRef": {
                                                                        "Source": "a"
                                                                    }
                                                                },
                                                                "Property": "Area",
                                                            }
                                                        }
                                                    ],
                                                    "Values": [
                                                        [
                                                            {
                                                                "Literal": {
                                                                    "Value": "'Connect all People'"
                                                                }
                                                            }
                                                        ],
                                                        [
                                                            {
                                                                "Literal": {
                                                                    "Value": "'Accountability for Discrimination/Misleading Content'"
                                                                }
                                                            }
                                                        ],
                                                        [
                                                            {
                                                                "Literal": {
                                                                    "Value": "'Digital Commons'"
                                                                }
                                                            }
                                                        ],
                                                        [
                                                            {
                                                                "Literal": {
                                                                    "Value": "'Regulation of AI'"
                                                                }
                                                            }
                                                        ],
                                                        [
                                                            {
                                                                "Literal": {
                                                                    "Value": "'Protect Data'"
                                                                }
                                                            }
                                                        ],
                                                        [
                                                            {
                                                                "Literal": {
                                                                    "Value": "'Internet Fragmentation'"
                                                                }
                                                            }
                                                        ],
                                                        [
                                                            {
                                                                "Literal": {
                                                                    "Value": "'Human Rights Online'"
                                                                }
                                                            }
                                                        ],
                                                        [
                                                            {
                                                                "Literal": {
                                                                    "Value": "'Other Area'"
                                                                }
                                                            }
                                                        ],
                                                    ],
                                                }
                                            }
                                        }
                                    ],
                                    "OrderBy": [
                                        {
                                            "Direction": 2,
                                            "Expression": {
                                                "Aggregation": {
                                                    "Expression": {
                                                        "Column": {
                                                            "Expression": {
                                                                "SourceRef": {
                                                                    "Source": "a"
                                                                }
                                                            },
                                                            "Property": "Core Principles",
                                                        }
                                                    },
                                                    "Function": 2,
                                                }
                                            },
                                        }
                                    ],
                                },
                                "Binding": {
                                    "Primary": {
                                        "Groupings": [{"Projections": [0, 1, 2, 3, 4]}]
                                    },
                                    "DataReduction": {
                                        "DataVolume": 3,
                                        "Primary": {"Window": {"Count": 500}},
                                    },
                                    "Version": 1,
                                },
                                "ExecutionMetricsKind": 1,
                            }
                        }
                    ]
                },
                "CacheKey": "",
                "QueryId": "",
                "ApplicationContext": {
                    "DatasetId": "fb1276c8-e98e-4b26-a7d3-24a40ae84000",
                    "Sources": [
                        {
                            "ReportId": "a70c1024-15f3-4f74-aa2e-2f1897acfdb6",
                            "VisualId": "fc23d492ddbe07d7e1a4",
                        }
                    ],
                },
            }
        ],
        "cancelQueries": [],
        "modelId": 933989,
    }

    payload_p2 = {
        "version": "1.0.0",
        "queries": [
            {
                "Query": {
                    "Commands": [
                        {
                            "SemanticQueryDataShapeCommand": {
                                "Query": {
                                    "Version": 2,
                                    "From": [
                                        {
                                            "Name": "a",
                                            "Entity": "All Areas combined",
                                            "Type": 0,
                                        },
                                        {
                                            "Name": "b",
                                            "Entity": "Demographics",
                                            "Type": 0,
                                        },
                                    ],
                                    "Select": [
                                        {
                                            "Column": {
                                                "Expression": {
                                                    "SourceRef": {"Source": "a"}
                                                },
                                                "Property": "Record ID",
                                            },
                                            "Name": "Record ID",
                                        },
                                        {
                                            "Column": {
                                                "Expression": {
                                                    "SourceRef": {"Source": "a"}
                                                },
                                                "Property": "Core Principles",
                                            },
                                            "Name": "All Areas combined.Core Principles",
                                        },
                                        {
                                            "Column": {
                                                "Expression": {
                                                    "SourceRef": {"Source": "a"}
                                                },
                                                "Property": "Commitments, pledges or actions",
                                            },
                                            "Name": "All Areas combined.Commitments, pledges or actions",
                                        },
                                        {
                                            "Column": {
                                                "Expression": {
                                                    "SourceRef": {"Source": "b"}
                                                },
                                                "Property": "Process description",
                                            },
                                            "Name": "Demographics.Process description",
                                        },
                                    ],
                                    "OrderBy": [
                                        {
                                            "Direction": 2,
                                            "Expression": {
                                                "Column": {
                                                    "Expression": {
                                                        "SourceRef": {"Source": "a"}
                                                    },
                                                    "Property": "Core Principles",
                                                    # "Property": "Record ID",
                                                    # "Property": "Area",
                                                }
                                            },
                                        }
                                    ],
                                    "Where": [
                                        {
                                            "Condition": {
                                                "In": {
                                                    "Expressions": [
                                                        {
                                                            "Column": {
                                                                "Expression": {
                                                                    "SourceRef": {
                                                                        "Source": "a"
                                                                    }
                                                                },
                                                                "Property": "Area",
                                                            }
                                                        }
                                                    ],
                                                    "Values": [
                                                        [
                                                            {
                                                                "Literal": {
                                                                    "Value": "'Accountability for Discrimination/Misleading Content'"
                                                                }
                                                            }
                                                        ],
                                                    ],
                                                }
                                            }
                                        },
                                        {
                                            "Condition": {
                                                "In": {
                                                    "Expressions": [
                                                        {
                                                            "Column": {
                                                                "Expression": {
                                                                    "SourceRef": {
                                                                        "Source": "a"
                                                                    }
                                                                },
                                                                "Property": "Record ID",
                                                            }
                                                        }
                                                    ],
                                                    "Values": [
                                                        [
                                                            {
                                                                "Literal": {
                                                                    "Value": "'638159590404564717'"
                                                                }
                                                            },
                                                        ],
                                                        [
                                                            {
                                                                "Literal": {
                                                                    "Value": "'638183478316757857'"
                                                                }
                                                            },
                                                        ],
                                                    ],
                                                }
                                            }
                                        },
                                    ],
                                },
                                "Binding": {
                                    "Primary": {
                                        "Groupings": [{"Projections": [0, 1, 2, 3]}]
                                    },
                                    # "Primary": {"Groupings": [{"Projections": [0]}]},
                                    "DataReduction": {
                                        "DataVolume": 3,
                                        "Primary": {"Top": {}},
                                        # "Primary": {"Window": {"Count": 500}},
                                    },
                                    "Version": 1,
                                },
                                "ExecutionMetricsKind": 1,
                            }
                        }
                    ]
                },
                "CacheKey": "",
                "QueryId": "",
                "ApplicationContext": {
                    "DatasetId": "fb1276c8-e98e-4b26-a7d3-24a40ae84000",
                    "Sources": [
                        {
                            "ReportId": "a70c1024-15f3-4f74-aa2e-2f1897acfdb6",
                            "VisualId": "58d5b49030dc6e9c802b",
                        }
                    ],
                },
            }
        ],
        "cancelQueries": [],
        "modelId": 933989,
    }

    # api url copied form the Headers section of Network>XHR
    api_url = "https://wabi-north-europe-j-primary-api.analysis.windows.net/public/reports/querydata?synchronous=true"
    headers = {
        "user_agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
        "X-Powerbi-Resourcekey": "84db278f-178b-4a18-a0db-3e57e8113b1f",
    }

    ##### START SCRAPING P1 #####

    df = page_1_scraping(api_url, payload_p1, headers)

    ##### SET RECORD IDS #####

    record_id = df["Record ID"].tolist()
    ids = [
        [
            {"Literal": {"Value": f"'{x}'"}},
        ]
        for x in record_id
    ]
    payload_p2["queries"][0]["Query"]["Commands"][0]["SemanticQueryDataShapeCommand"][
        "Query"
    ]["Where"][1]["Condition"]["In"]["Values"] = ids

    ##### START SCRAPING P2 #####

    local_dir = "data"
    export_path = Path(local_dir, "powerBI.csv")
    df = page_2_scraping(api_url, payload_p2, headers, df)
    df.to_csv(export_path, index=False)

    print("Scrapping completed")


if __name__ == "__main__":
    omdena_ungdc_etl_scrap_pbi_parent()
# Out:
# >>> MAIN TABLE
# {'jobIds': ['16b89e02-2e68-4037-affa-badb02b19f92'], 'results': [{'jobId': '16b89e02-2e68-4037-affa-badb02b19f92', 'result': {'data': {'timestamp': '2024-09-03T14:48:34.382Z', 'rootActivityId': '21aaaf5f-52ac-482f-8ef4-b7833c7f0c5f', 'descriptor': {'Select': [{'Kind': 1, 'Depth': 0, 'Value': 'G0', 'GroupKeys': [{'Source': {'Entity': 'Demographics', 'Property': 'Type'}, 'Calc': 'G0', 'IsSameAsSelect': True}], 'Name': 'Demographics.Type'}, {'Kind': 1, 'Depth': 0, 'Value': 'G1', 'GroupKeys': [{'Source': {'Entity': 'Demographics', 'Property': 'Location formatted'}, 'Calc': 'G1', 'IsSameAsSelect': True}], 'Name': 'Demographics.Location formatted'}, {'Kind': 1, 'Depth': 0, 'Value': 'G2', 'GroupKeys': [{'Source': {'Entity': 'Demographics', 'Property': 'Contact Name'}, 'Calc': 'G2', 'IsSameAsSelect': True}], 'Name': 'Demographics.Contact Name'}, {'Kind': 1, 'Depth': 0, 'Value': 'G3', 'GroupKeys': [{'Source': {'Entity': 'Demographics', 'Property': 'Entity Name'}, 'Calc': 'G3', 'IsSameAsSelect': True}], 'Name': 'Demographics.Entity Name'}, {'Kind': 1, 'Depth': 0, 'Value': 'G4', 'GroupKeys': [{'Source': {'Entity': 'All Areas combined', 'Property': 'Record ID'}, 'Calc': 'G4', 'IsSameAsSelect': True}], 'Name': 'All Areas combined.Record ID'}], 'Expressions': {'Primary': {'Groupings': [{'Keys': [{'Source': {'Entity': 'Demographics', 'Property': 'Type'}, 'Select': 0}, {'Source': {'Entity': 'Demographics', 'Property': 'Location formatted'}, 'Select': 1}, {'Source': {'Entity': 'Demographics', 'Property': 'Contact Name'}, 'Select': 2}, {'Source': {'Entity': 'Demographics', 'Property': 'Entity Name'}, 'Select': 3}, {'Source': {'Entity': 'All Areas combined', 'Property': 'Record ID'}, 'Select': 4}], 'Member': 'DM0'}]}}, 'Version': 2}, 'metrics': {'Version': '1.0.0', 'Events': [{'Id': '1e49dae2-aeb5-4228-9f71-98c1a3e59fb1', 'Name': 'Execute Semantic Query', 'Component': 'DSE', 'Start': '2024-09-03T14:48:34.3821535Z', 'End': '2024-09-03T14:48:34.4134078Z'}, {'Id': '4fae221e-ecd5-494d-8725-552958f1e8b4', 'ParentId': '1e49dae2-aeb5-4228-9f71-98c1a3e59fb1', 'Name': 'Execute DAX Query', 'Component': 'DSE', 'Start': '2024-09-03T14:48:34.3821535Z', 'End': '2024-09-03T14:48:34.3977788Z', 'Metrics': {'RowCount': 359}}, {'Id': '30F608B9-BC31-4F89-82A3-BFA8D6B03296', 'ParentId': '4fae221e-ecd5-494d-8725-552958f1e8b4', 'Name': 'Execute Query', 'Component': 'AS', 'Start': '2024-09-03T14:48:34.403Z', 'End': '2024-09-03T14:48:34.407Z'}, {'Id': '78B35E3F-8092-40C6-82D4-E4B7F51121A2', 'ParentId': '30F608B9-BC31-4F89-82A3-BFA8D6B03296', 'Name': 'Serialize Rowset', 'Component': 'AS', 'Start': '2024-09-03T14:48:34.407Z', 'End': '2024-09-03T14:48:34.407Z'}]}, 'fromCache': False, 'dsr': {'Version': 2, 'MinorVersion': 1, 'DS': [{'N': 'DS0', 'PH': [{'DM0': [{'S': [{'N': 'G0', 'T': 1, 'DN': 'D0'}, {'N': 'G1', 'T': 1, 'DN': 'D1'}, {'N': 'G2', 'T': 1, 'DN': 'D2'}, {'N': 'G3', 'T': 1, 'DN': 'D3'}, {'N': 'G4', 'T': 1, 'DN': 'D4'}], 'C': [0, 0, 0, 0, 0]}, {'C': [1, 1, 1], 'R': 3}, {'C': [2, 2, 2], 'R': 3}, {'C': [3, 3, 3], 'R': 3}, {'C': [4], 'R': 15}, {'C': [4, 4, 5], 'R': 3}, {'C': [5, 5, 6], 'R': 3}, {'C': [6, 6, 7], 'R': 3}, {'C': [7, 7, 8], 'R': 3}, {'C': [1, 8, 8, 9], 'R': 1}, {'C': [9, 9, 10], 'R': 3}, {'C': [1, 2, 10, 10, 11]}, {'C': [3, 11, 11, 12], 'R': 1}, {'C': [0, 12, 12, 13], 'R': 1}, {'C': [13, 13, 14], 'R': 3}, {'C': [14, 14, 15], 'R': 3}, {'C': [15, 15, 16], 'R': 3}, {'C': [16, 16, 17], 'R': 3}, {'C': [17, 17, 18], 'R': 3}, {'C': [18, 18, 19], 'R': 3}, {'C': [19, 19, 20], 'R': 3}, {'C': [4, 20, 20, 21], 'R': 1}, {'C': [5, 21, 21, 22], 'R': 1}, {'C': [2, 6, 22, 22, 23]}, {'C': [0, 23, 23, 24], 'R': 1}, {'C': [24, 24, 25], 'R': 3}, {'C': [25, 25, 26], 'R': 3}, {'C': [3, 26, 26, 27], 'R': 2}, {'C': [27, 28], 'R': 11}, {'C': [28, 29], 'R': 11}, {'C': [29, 30], 'R': 11}, {'C': [5, 30, 31], 'R': 9}, {'C': [31, 32], 'R': 11}, {'C': [4, 7, 32, 27, 33]}, {'C': [0, 33, 28, 34], 'R': 1}, {'C': [34, 29, 35], 'R': 3}, {'C': [35, 30, 36], 'R': 3}, {'C': [36, 31, 37], 'R': 3 ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-211135afa761> in <cell line: 516>()
#     515
#     516 if __name__ == "__main__":
# --> 517     omdena_ungdc_etl_scrap_pbi_parent()
#
# <ipython-input-23-211135afa761> in omdena_ungdc_etl_scrap_pbi_parent()
#     489     ##### START SCRAPING P1 #####
#     490
# --> 491     df = page_1_scraping(api_url, payload_p1, headers)
#     492
#     493     ##### SET RECORD IDS #####
#
# <ipython-input-23-211135afa761> in page_1_scraping(api_url, payload, headers)
#      21     print(table_data)
#      22
# ---> 23     return extract(table_data)
#      24
#      25
#
# TypeError: extract() missing 1 required positional argument: 'output_file'
